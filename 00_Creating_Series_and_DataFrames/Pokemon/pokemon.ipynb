# %% [markdown]
# # Pokemon

# %% [markdown]
# ### Introduction:
#
# This time you will create the data.
#
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Create a data dictionary that looks like the DataFrame below

# %%
from typing_extensions import dataclass_transform
df = pd.read_csv("pokemon.csv")

data_dict = pd.DataFrame({
    "Column Name": df.columns,
    "Data Type": [str(dtype) for dtype in df.dtypes],
    "Non-Null Count": df.notnull().sum().values,
    "Unique Values": df.nunique().values
})

data_dict
# Out:
#    Column Name Data Type  Non-Null Count  Unique Values
# 0            #     int64             800            721
# 1         Name    object             800            800
# 2       Type 1    object             800             18
# 3       Type 2    object             414             18
# 4        Total     int64             800            200
# 5           HP     int64             800             94
# 6       Attack     int64             800            111
# 7      Defense     int64             800            103
# 8      Sp. Atk     int64             800            105
# 9      Sp. Def     int64             800             92
# 10       Speed     int64             800            108
# 11  Generation     int64             800              6
# 12   Legendary      bool             800              2

# %% [markdown]
# ### Step 3. Assign it to a variable called pokemon

# %%
pokemon = pd.read_csv("pokemon.csv")

pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ### Step 4. Ops...it seems the DataFrame columns are in alphabetical order. Place  the order of the columns as name, type, hp, evolution, pokedex

# %%
pokemon = pokemon[["Name", "Type 1", "Type 2", "HP"]]

pokemon.head()
# Out:
#                     Name Type 1  Type 2  HP
# 0              Bulbasaur  Grass  Poison  45
# 1                Ivysaur  Grass  Poison  60
# 2               Venusaur  Grass  Poison  80
# 3  VenusaurMega Venusaur  Grass  Poison  80
# 4             Charmander   Fire     NaN  39

# %% [markdown]
# ### Step 5. Add another column called place, and insert what you have in mind.

# %%
pokemon["place"] = "Kanto"

pokemon.head()
# Out:
#                     Name Type 1  Type 2  HP  place
# 0              Bulbasaur  Grass  Poison  45  Kanto
# 1                Ivysaur  Grass  Poison  60  Kanto
# 2               Venusaur  Grass  Poison  80  Kanto
# 3  VenusaurMega Venusaur  Grass  Poison  80  Kanto
# 4             Charmander   Fire     NaN  39  Kanto

# %% [markdown]
# ### Step 6. Present the type of each column

# %%
pokemon.dtypes
# Out:
# Name      object
# Type 1    object
# Type 2    object
# HP         int64
# place     object
# dtype: object

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
## Which Pokémon has the highest HP, and what is its Type?
highest_hp = pokemon.loc[pokemon["HP"].idxmax(), ["Name", "HP", "Type 1", "Type 2"]]
highest_hp
# Out:
# Name      Blissey
# HP            255
# Type 1     Normal
# Type 2        NaN
# Name: 261, dtype: object
